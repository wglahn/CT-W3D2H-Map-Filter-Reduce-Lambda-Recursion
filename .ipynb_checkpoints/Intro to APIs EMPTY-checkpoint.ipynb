# %% [markdown]
# # Working with APIs

# %% [markdown]
# API stands for Application programming interface<br>
# APIs are a way for applications to talk to eachother<br>
# In python we use the requests package to handle the connection<br>
# <small><strong>Note: It is requests with an s not request(this is a different package)</strong></small><br>
# Most API's communicate with data in the form of JSON<br>
# JSON stands for JavaScript Object Notation

# %%
#import the packages we need:
import requests, json

# %% [markdown]
# We will be connecting to the Ergast F1 Racer API today:
# http://ergast.com/mrd/
#
# to view JSON data nicely in the Chrome browser install the extension JSONview

# %%
help(requests)
# Out:
# Help on package requests:
#
# NAME
#     requests
#
# DESCRIPTION
#     Requests HTTP Library
#     ~~~~~~~~~~~~~~~~~~~~~
#
#     Requests is an HTTP library, written in Python, for human beings.
#     Basic GET usage:
#
#        >>> import requests
#        >>> r = requests.get('https://www.python.org')
#        >>> r.status_code
#        200
#        >>> b'Python is a programming language' in r.content
#        True
#
#     ... or POST:
#
#        >>> payload = dict(key1='value1', key2='value2')
#        >>> r = requests.post('https://httpbin.org/post', data=payload)
#        >>> print(r.text)
#        {
#          ...
#          "form": {
#            "key1": "value1",
#            "key2": "value2"
#          },
#          ...
#        }
#
#     The other HTTP methods are supported - see `requests.api`. Full documentation
#     is at <https://requests.readthedocs.io>.
#
#     :copyright: (c) 2017 by Kenneth Reitz.
#     :license: Apache 2.0, see LICENSE for more details.
#
# ...

# %%
url = "https://ergast.com/api/f1/2020/1/driverStandings.json"

# %%
#response object
response = requests.get(url)
print(response)
# Out:
# <Response [200]>

# %%
#check and make sure we got a successful response from the API
response.ok
# Out:
# True

# %%
#view the response as a JSON
response.json()
# Out:
# {'MRData': {'xmlns': 'http://ergast.com/mrd/1.4',
#   'series': 'f1',
#   'url': 'http://ergast.com/api/f1/2020/1/driverstandings.json',
#   'limit': '30',
#   'offset': '0',
#   'total': '20',
#   'StandingsTable': {'season': '2020',
#    'round': '1',
#    'StandingsLists': [{'season': '2020',
#      'round': '1',
#      'DriverStandings': [{'position': '1',
#        'positionText': '1',
#        'points': '25',
#        'wins': '1',
#        'Driver': {'driverId': 'bottas',
#         'permanentNumber': '77',
#         'code': 'BOT',
#         'url': 'http://en.wikipedia.org/wiki/Valtteri_Bottas',
#         'givenName': 'Valtteri',
#         'familyName': 'Bottas',
#         'dateOfBirth': '1989-08-28',
#         'nationality': 'Finnish'},
#        'Constructors': [{'constructorId': 'mercedes',
#          'url': 'http://en.wikipedia.org/wiki/Mercedes-Benz_in_Formula_One',
#          'name': 'Mercedes',
#          'nationality': 'German'}]},
#       {'position': '2',
# ...

# %%
type(response.json())
# Out:
# dict

# %%
# We only want the Driver Standings
data = response.json()["MRData"]["StandingsTable"]["StandingsLists"][0]["DriverStandings"]
print(data)
# Out:
# [{'position': '1', 'positionText': '1', 'points': '25', 'wins': '1', 'Driver': {'driverId': 'bottas', 'permanentNumber': '77', 'code': 'BOT', 'url': 'http://en.wikipedia.org/wiki/Valtteri_Bottas', 'givenName': 'Valtteri', 'familyName': 'Bottas', 'dateOfBirth': '1989-08-28', 'nationality': 'Finnish'}, 'Constructors': [{'constructorId': 'mercedes', 'url': 'http://en.wikipedia.org/wiki/Mercedes-Benz_in_Formula_One', 'name': 'Mercedes', 'nationality': 'German'}]}, {'position': '2', 'positionText': '2', 'points': '18', 'wins': '0', 'Driver': {'driverId': 'leclerc', 'permanentNumber': '16', 'code': 'LEC', 'url': 'http://en.wikipedia.org/wiki/Charles_Leclerc', 'givenName': 'Charles', 'familyName': 'Leclerc', 'dateOfBirth': '1997-10-16', 'nationality': 'Monegasque'}, 'Constructors': [{'constructorId': 'ferrari', 'url': 'http://en.wikipedia.org/wiki/Scuderia_Ferrari', 'name': 'Ferrari', 'nationality': 'Italian'}]}, {'position': '3', 'positionText': '3', 'points': '16', 'wins': '0', 'Driver': 
# ...

# %%
type(data)
# Out:
# list

# %%
def get_racer_info(data):
    new_data=[]
    for racer in data:
        racer_dict={}
        racer_name = f'{racer["Driver"]["givenName"]} {racer["Driver"]["familyName"]}'
        racer_dict[racer_name] = {
            "first_name": racer['Driver']['givenName'],
            "last_name": racer["Driver"]["familyName"],
            "postion": racer["position"],
            "wins": racer["wins"],
            "DOB": racer["Driver"]["dateOfBirth"],
            "nationality": racer["Driver"]["nationality"],
            "constructor": racer["Constructors"][0]["name"]
        }
        new_data.append(racer_dict)
    return new_data

print(get_racer_info(data))
# Out:
# [{'Valtteri Bottas': {'first_name': 'Valtteri', 'last_name': 'Bottas', 'postion': '1', 'wins': '1', 'DOB': '1989-08-28', 'nationality': 'Finnish', 'constructor': 'Mercedes'}}, {'Charles Leclerc': {'first_name': 'Charles', 'last_name': 'Leclerc', 'postion': '2', 'wins': '0', 'DOB': '1997-10-16', 'nationality': 'Monegasque', 'constructor': 'Ferrari'}}, {'Lando Norris': {'first_name': 'Lando', 'last_name': 'Norris', 'postion': '3', 'wins': '0', 'DOB': '1999-11-13', 'nationality': 'British', 'constructor': 'McLaren'}}, {'Lewis Hamilton': {'first_name': 'Lewis', 'last_name': 'Hamilton', 'postion': '4', 'wins': '0', 'DOB': '1985-01-07', 'nationality': 'British', 'constructor': 'Mercedes'}}, {'Carlos Sainz': {'first_name': 'Carlos', 'last_name': 'Sainz', 'postion': '5', 'wins': '0', 'DOB': '1994-09-01', 'nationality': 'Spanish', 'constructor': 'McLaren'}}, {'Sergio Pérez': {'first_name': 'Sergio', 'last_name': 'Pérez', 'postion': '6', 'wins': '0', 'DOB': '1990-01-26', 'nationality': 'Mexica
# ...

# %%
response = requests.get(url)

def get_driver_info_by_year_and_round(year, r):
    url = f"https://ergast.com/api/f1/{year}/{r}/driverStandings.json"
    if not response.json()["MRData"]["StandingsTable"]["StandingsLists"]:
        return "We had an error loading your data or your year/round is not in the database"
    data = response.json()["MRData"]["StandingsTable"]["StandingsLists"][0]["DriverStandings"]
    return get_racer_info(data)

get_driver_info_by_year_and_round(2020,3)[0:5]
# Out:
# [{'Lewis Hamilton': {'first_name': 'Lewis',
#    'last_name': 'Hamilton',
#    'postion': '1',
#    'wins': '2',
#    'DOB': '1985-01-07',
#    'nationality': 'British',
#    'constructor': 'Mercedes'}},
#  {'Valtteri Bottas': {'first_name': 'Valtteri',
#    'last_name': 'Bottas',
#    'postion': '2',
#    'wins': '1',
#    'DOB': '1989-08-28',
#    'nationality': 'Finnish',
#    'constructor': 'Mercedes'}},
#  {'Max Verstappen': {'first_name': 'Max',
#    'last_name': 'Verstappen',
#    'postion': '3',
#    'wins': '0',
#    'DOB': '1997-09-30',
#    'nationality': 'Dutch',
#    'constructor': 'Red Bull'}},
#  {'Lando Norris': {'first_name': 'Lando',
#    'last_name': 'Norris',
#    'postion': '4',
#    'wins': '0',
#    'DOB': '1999-11-13',
#    'nationality': 'British',
#    'constructor': 'McLaren'}},
#  {'Alexander Albon': {'first_name': 'Alexander',
#    'last_name': 'Albon',
#    'postion': '5',
#    'wins': '0',
#    'DOB': '1996-03-23',
#    'nationality': 'Thai',
# ...

# %% [markdown]
# # <strong>Homework</strong>
# check out this Pokemon API https://pokeapi.co/
# Use the requests package to connect to this API and get and store data for 5 different pokemon.
# Get the pokemons: name, atleast one ability's name, base_experience, and the URL for its sprite (an image that shows up on screen) for the 'front_shiny'

# %%
import requests, json

# Gather information about 5 different Pokemon
# Name, 1 ability's name, base_experience, and the URL for its sprite (front_shiny) 

# estbalish pokemon name to get the correct link
# because all the links are set up with the same dictionary line up
# then we establish the route to each piece of information using a new dictionary
# return the new dictionary
# invoke the function 5 times with 5 different pokemon names

names = ['pikachu','slaking','golem','nosepass','arbok']

def get_poke_info(name):
    url = f"https://pokeapi.co/api/v2/pokemon/{name}"
    response = requests.get(url)
    if response.ok:
        poke_dict={
            "name":response.json()['forms'][0]['name'],
            "ability":response.json()['abilities'][0]['ability']['name'],
            "base xp":response.json()['base_experience'],
            "sprite": response.json()['sprites']['front_shiny']
            }
        return poke_dict
    else:
        print("Incorrect pokemon name. Please try again.")
        
poke_info = []
for name in names:
    poke_info.append(get_poke_info(name))
    
print(poke_info)
# Out:
# [{'name': 'pikachu', 'ability': 'static', 'base xp': 112, 'sprite': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/shiny/25.png'}, {'name': 'slaking', 'ability': 'truant', 'base xp': 252, 'sprite': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/shiny/289.png'}, {'name': 'golem', 'ability': 'rock-head', 'base xp': 223, 'sprite': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/shiny/76.png'}, {'name': 'nosepass', 'ability': 'sturdy', 'base xp': 75, 'sprite': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/shiny/299.png'}, {'name': 'arbok', 'ability': 'intimidate', 'base xp': 157, 'sprite': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/shiny/24.png'}]
